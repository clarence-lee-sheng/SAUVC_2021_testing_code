# %%
import tfx
import tensorflow as tf 
from tfx.components import ImportExampleGen
from tfx.proto import example_gen_pb2
from tfx.orchestration.experimental.interactive.interactive_context import InteractiveContext

# %%
print(tfx.__version__)
print(tf.__version__)
# Out:
# 0.30.0
# 2.4.1

# %%
_DATA_ROOT = 'gate_dataset'

# %%
context = InteractiveContext()
# Out:
# WARNING:absl:InteractiveContext pipeline_root argument not provided: using temporary directory C:\Users\Clarence\AppData\Local\Temp\tfx-interactive-2021-07-04T10_06_58.610819-87mzg8u9 as root for pipeline outputs.
# WARNING:absl:InteractiveContext metadata_connection_config not provided: using SQLite ML Metadata database at C:\Users\Clarence\AppData\Local\Temp\tfx-interactive-2021-07-04T10_06_58.610819-87mzg8u9\metadata.sqlite.

# %%
input_config = example_gen_pb2.Input(
   splits=[
       example_gen_pb2.Input.Split(name='train', pattern='test/*'),
       example_gen_pb2.Input.Split(name='test', pattern='test/*')
   ]
)

# input = proto.Input(splits=[
#                 example_gen_pb2.Input.Split(name='train', pattern='train/*'),
#                 example_gen_pb2.Input.Split(name='eval', pattern='eval/*')
#             ])

# %%
example_gen = ImportExampleGen(input_base=_DATA_ROOT)
context.run(example_gen)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-46-07b74ed497cc> in <module>
#       1 example_gen = ImportExampleGen(input_base=_DATA_ROOT, input_config=input_config)
# ----> 2 context.run(example_gen)
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\tfx\orchestration\experimental\interactive\interactive_context.py in run_if_ipython(*args, **kwargs)
#      66       # __IPYTHON__ variable is set by IPython, see
#      67       # https://ipython.org/ipython-doc/rel-0.10.2/html/interactive/reference.html#embedding-ipython.
# ---> 68       return fn(*args, **kwargs)
#      69     else:
#      70       absl.logging.warning(
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\tfx\orchestration\experimental\interactive\interactive_context.py in run(self, component, enable_cache, beam_pipeline_args)
#     186         telemetry_utils.LABEL_TFX_RUNNER: runner_label,
#     187     }):
# --> 188       execution_id = launcher.launch().execution_id
#     189
#     190     return execution_result.ExecutionResult(
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\tfx\orchestration\launcher\base_component_launcher.py in launch(self)
#     204       # be immutable in this context.
#     205       # output_dict can still be changed, specifically properties.
# --> 206       self._run_executor(execution_decision.execution_id,
#     207                          copy.deepcopy(execution_decision.input_dict),
#     208                          execution_decision.output_dict,
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\tfx\orchestration\launcher\in_process_component_launcher.py in _run_executor(self, execution_id, input_dict, output_dict, exec_properties)
#      69     # be immutable in this context.
#      70     # output_dict can still be changed, specifically properties.
# ---> 71     executor.Do(
#      72         copy.deepcopy(input_dict), output_dict, copy.deepcopy(exec_properties))
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\tfx\components\example_gen\base_example_gen_executor.py in Do(self, input_dict, output_dict, exec_properties)
#     314     logging.info('Generating examples.')
#     315     with self._make_beam_pipeline() as pipeline:
# --> 316       example_splits = self.GenerateExamplesByBeam(pipeline, exec_properties)
#     317
#     318       # pylint: disable=expression-not-assigned, no-value-for-parameter
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\tfx\components\example_gen\base_example_gen_executor.py in GenerateExamplesByBeam(self, pipeline, exec_properties)
#     252       for split in input_config.splits:
#     253         examples = (
# --> 254             pipeline
#     255             | 'InputToRecord[{}]'.format(split.name) >>
#     256             # pylint: disable=no-value-for-parameter
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\apache_beam\transforms\ptransform.py in __ror__(self, pvalueish, _unused)
#    1084
#    1085   def __ror__(self, pvalueish, _unused=None):
# -> 1086     return self.transform.__ror__(pvalueish, self.label)
#    1087
#    1088   def expand(self, pvalue):
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\apache_beam\transforms\ptransform.py in __ror__(self, left, label)
#     599     pvalueish = _SetInputPValues().visit(pvalueish, replacements)
#     600     self.pipeline = p
# --> 601     result = p.apply(self, pvalueish, label)
#     602     if deferred:
#     603       return result
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\apache_beam\pipeline.py in apply(self, transform, pvalueish, label)
#     649       try:
#     650         old_label, transform.label = transform.label, label
# --> 651         return self.apply(transform, pvalueish)
#     652       finally:
#     653         transform.label = old_label
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\apache_beam\pipeline.py in apply(self, transform, pvalueish, label)
#     692         transform.type_check_inputs(pvalueish)
#     693
# --> 694       pvalueish_result = self.runner.apply(transform, pvalueish, self._options)
#     695
#     696       if type_options is not None and type_options.pipeline_type_check:
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\apache_beam\runners\runner.py in apply(self, transform, input, options)
#     186       m = getattr(self, 'apply_%s' % cls.__name__, None)
#     187       if m:
# --> 188         return m(transform, input, options)
#     189     raise NotImplementedError(
#     190         'Execution of [%s] not implemented in runner %s.' % (transform, self))
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\apache_beam\runners\runner.py in apply_PTransform(self, transform, input, options)
#     216   def apply_PTransform(self, transform, input, options):
#     217     # The base case of apply is to call the transform's expand.
# --> 218     return transform.expand(input)
#     219
#     220   def run_transform(self,
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\apache_beam\transforms\ptransform.py in expand(self, pcoll)
#     990       # Might not be a function.
#     991       pass
# --> 992     return self._fn(pcoll, *args, **kwargs)
#     993
#     994   def default_label(self):
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\tfx\components\example_gen\import_example_gen\executor.py in ImportRecord(pipeline, exec_properties, split_pattern)
#      93
#      94       serialized_records = (
# ---> 95           pipeline
#      96           # pylint: disable=no-value-for-parameter
#      97           | _ImportSerializedRecord(exec_properties, split_pattern))
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\apache_beam\pvalue.py in __or__(self, ptransform)
#     140
#     141   def __or__(self, ptransform):
# --> 142     return self.pipeline.apply(ptransform, self)
#     143
#     144
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\apache_beam\pipeline.py in apply(self, transform, pvalueish, label)
#     692         transform.type_check_inputs(pvalueish)
#     693
# --> 694       pvalueish_result = self.runner.apply(transform, pvalueish, self._options)
#     695
#     696       if type_options is not None and type_options.pipeline_type_check:
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\apache_beam\runners\runner.py in apply(self, transform, input, options)
#     186       m = getattr(self, 'apply_%s' % cls.__name__, None)
#     187       if m:
# --> 188         return m(transform, input, options)
#     189     raise NotImplementedError(
#     190         'Execution of [%s] not implemented in runner %s.' % (transform, self))
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\apache_beam\runners\runner.py in apply_PTransform(self, transform, input, options)
#     216   def apply_PTransform(self, transform, input, options):
#     217     # The base case of apply is to call the transform's expand.
# --> 218     return transform.expand(input)
#     219
#     220   def run_transform(self,
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\apache_beam\transforms\ptransform.py in expand(self, pcoll)
#     990       # Might not be a function.
#     991       pass
# --> 992     return self._fn(pcoll, *args, **kwargs)
#     993
#     994   def default_label(self):
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\tfx\components\example_gen\import_example_gen\executor.py in _ImportSerializedRecord(pipeline, exec_properties, split_pattern)
#      59           # TODO(jyzhao): support multiple input container format.
#      60           | 'ReadFromTFRecord' >>
# ---> 61           beam.io.ReadFromTFRecord(file_pattern=input_split_pattern))
#      62
#      63
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\apache_beam\io\tfrecordio.py in __init__(self, file_pattern, coder, compression_type, validate)
#     254     """
#     255     super(ReadFromTFRecord, self).__init__()
# --> 256     self._source = _TFRecordSource(
#     257         file_pattern, coder, compression_type, validate)
#     258
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\apache_beam\io\tfrecordio.py in __init__(self, file_pattern, coder, compression_type, validate)
#     169   def __init__(self, file_pattern, coder, compression_type, validate):
#     170     """Initialize a TFRecordSource.  See ReadFromTFRecord for details."""
# --> 171     super(_TFRecordSource, self).__init__(
#     172         file_pattern=file_pattern,
#     173         compression_type=compression_type,
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\apache_beam\io\filebasedsource.py in __init__(self, file_pattern, min_bundle_size, compression_type, splittable, validate)
#     121     self._splittable = splittable
#     122     if validate and file_pattern.is_accessible():
# --> 123       self._validate()
#     124
#     125   def display_data(self):
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\apache_beam\options\value_provider.py in _f(self, *args, **kwargs)
#     194         if not obj.is_accessible():
#     195           raise error.RuntimeValueProviderError('%s not accessible' % obj)
# --> 196       return fnc(self, *args, **kwargs)
#     197
#     198     return _f
#
# ~\Documents\School\Internship\DSO\dso-env\lib\site-packages\apache_beam\io\filebasedsource.py in _validate(self)
#     184     match_result = FileSystems.match([pattern], limits=[1])[0]
#     185     if len(match_result.metadata_list) <= 0:
# --> 186       raise IOError('No files found based on the file pattern %s' % pattern)
#     187
#     188   def split(
#
# OSError: No files found based on the file pattern gate_dataset\test/*
